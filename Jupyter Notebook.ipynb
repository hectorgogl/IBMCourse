# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Hector Gomez**
# <br>
# Student

# %% [markdown]
# *I want to become a data scientist because i love programming and finding patterns in the data*

# %% [markdown]
# ### This code returns the value of x^2

# %%
def xsq(x):
    return x**2
xsq(7)
# Out:
# 49

# %% [markdown]
# 1. Item1
# 2. Item 2
# <br>
#
# [google](www.google.com)
# <br>
#
# <img src="https://rotulosmatesanz.com/wp-content/uploads/2017/09/2000px-Google_G_Logo.svg_.png" width="37" height="37" />
